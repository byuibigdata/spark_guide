# %%
import pandas as pd
import numpy as np
import os
from pyspark import SparkConf #, SparkContext 
from pyspark.sql import SparkSession #, SQLContext https://spark.apache.org/docs/1.6.1/sql-programming-guide.html
from pyspark.sql import functions as F # access to the sql functions https://spark.apache.org/docs/latest/api/python/pyspark.sql.html#module-pyspark.sql.functions
from IPython.display import HTML

# %%
warehouse_location = os.path.abspath('../../../data/spark-warehouse')
print(warehouse_location)
# make sure you have set the warehouse location to 'hom/jovyan/data/spark-warehouse'
# Out:
# /home/jovyan/data/spark-warehouse

# %%
if os.path.normpath("/home/jovyan/data/spark-warehouse") != warehouse_location:
    print('\x1b[6;37;41m' + 'Your path is not correct' + '\x1b[0m')

# %%
# Create the session
conf = (SparkConf()
    .set("spark.ui.port", "4041")
    .set('spark.jars', '/home/jovyan/scratch/postgresql-42.2.18.jar')
    .set("spark.sql.inMemoryColumnarStorage.compressed", True) # default
    .set("spark.sql.inMemoryColumnarStorage.batchSize",10000) # default
    .set("spark.sql.warehouse.dir", warehouse_location) # set above
    .set("spark.driver.memory", "7g")    
    )

# Create the Session (used to be context)
# you can move the number up or down depending on your memory and processors "local[*]" will use all.
spark = SparkSession.builder \
    .master("local[3]") \
    .appName('test') \
    .config(conf=conf) \
    .getOrCreate()

# %%
# spark.stop()

# %%
properties = {
    'driver': 'org.postgresql.Driver',
    'url': 'jdbc:postgresql://c451_db_1:5432/irs990',
    'user': 'postgres',
    'password': 'postgres1234',
}

# %%
# schema table

schema = spark.read \
    .format('jdbc') \
    .option('driver', properties['driver']) \
    .option('url', properties['url']) \
    .option('dbtable', "information_schema.tables") \
    .option('user', properties['user']) \
    .load()

# %%
tables = schema.toPandas().filter(['table_catalog', 'table_schema', 'table_name']).query('table_schema == "public"')

# %%
HTML(tables.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>table_catalog</th>
#       <th>table_schema</th>
#       <th>table_name</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>address_table</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>cmsid_eins</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>django_migrations</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>excess_benefits</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>excess_benefits_types</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>filing_filing</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>fl_loans_from</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>insider_assistance</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>insider_assistance_types</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>insider_transactions</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>insider_transactions_types</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>loans</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>loans_from</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>loans_from_types</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>loans_to</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>loans_to_types</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>metadata_description</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>metadata_group</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>metadata_linenumber</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>metadata_schedulepart</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>metadata_variable</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>not_in_cms</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>org_types</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>part_vi_excerpt</td>
#     </tr>
#     <tr>
#       <th>34</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>pfrb_address_table</td>
#     </tr>
#     <tr>
#       <th>35</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>pfrb_list</td>
#     </tr>
#     <tr>
#       <th>38</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>return_cntrctrcmpnstn</td>
#     </tr>
#     <tr>
#       <th>39</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>return_ez_part_0</td>
#     </tr>
#     <tr>
#       <th>40</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>return_ez_part_i</td>
#     </tr>
#     <tr>
#       <th>41</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>return_ez_part_ii</td>
#     </tr>
#     <tr>
#       <th>42</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>return_ez_part_iii</td>
#     </tr>
#     <tr>
#       <th>43</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>return_ez_part_iv</td>
#     </tr>
#     <tr>
#       <th>44</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>return_ez_part_v</td>
#     </tr>
#     <tr>
#       <th>45</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>return_ez_part_vi</td>
#     </tr>
#     <tr>
#       <th>48</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>return_ezcmpnstnhghstpdempl</td>
#     </tr>
#     <tr>
#       <th>183</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>return_ezcmpnstnofhghstpdcntrct</td>
#     </tr>
#     <tr>
#       <th>221</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>return_ezfrgnfnnclaccntcntrycd</td>
#     </tr>
#     <tr>
#       <th>231</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>return_ezfrgnoffccntrycd</td>
#     </tr>
#     <tr>
#       <th>232</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>return_ezoffcrdrctrtrstempl</td>
#     </tr>
#     <tr>
#       <th>233</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>return_ezprgrmsrvcaccmplshmnt</td>
#     </tr>
#     <tr>
#       <th>234</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>return_ezspclcndtndsc</td>
#     </tr>
#     <tr>
#       <th>235</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>return_ezsttswhrcpyofrtrnisfldcd</td>
#     </tr>
#     <tr>
#       <th>236</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>return_frgncntrycd</td>
#     </tr>
#     <tr>
#       <th>237</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>return_frm990prtviisctna</td>
#     </tr>
#     <tr>
#       <th>238</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>return_othrexpnss</td>
#     </tr>
#     <tr>
#       <th>239</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>return_othrrvnmsc</td>
#     </tr>
#     <tr>
#       <th>240</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>return_part_0</td>
#     </tr>
#     <tr>
#       <th>241</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>return_part_i</td>
#     </tr>
#     <tr>
#       <th>242</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>return_part_iii</td>
#     </tr>
#     <tr>
#       <th>243</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>return_part_iv</td>
#     </tr>
#     <tr>
#       <th>244</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>return_part_ix</td>
#     </tr>
#     <tr>
#       <th>245</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>return_part_v</td>
#     </tr>
#     <tr>
#       <th>246</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>return_part_vi</td>
#     </tr>
#     <tr>
#       <th>247</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>return_part_vii</td>
#     </tr>
#     <tr>
#       <th>248</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>return_part_viii</td>
#     </tr>
#     <tr>
#       <th>249</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>return_part_x</td>
#     </tr>
#     <tr>
#       <th>250</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>return_part_xi</td>
#     </tr>
#     <tr>
#       <th>251</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>return_part_xii</td>
#     </tr>
#     <tr>
#       <th>252</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>return_pf_part_0</td>
#     </tr>
#     <tr>
#       <th>253</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>return_pf_part_i</td>
#     </tr>
#     <tr>
#       <th>254</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>return_pf_part_ii</td>
#     </tr>
#     <tr>
#       <th>255</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>return_pf_part_iii</td>
#     </tr>
#     <tr>
#       <th>256</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>return_pf_part_iv</td>
#     </tr>
#     <tr>
#       <th>257</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>return_pf_part_ixa</td>
#     </tr>
#     <tr>
#       <th>258</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>return_pf_part_ixb</td>
#     </tr>
#     <tr>
#       <th>259</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>return_pf_part_v</td>
#     </tr>
#     <tr>
#       <th>260</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>return_pf_part_vi</td>
#     </tr>
#     <tr>
#       <th>261</th>
#       <td>irs990</td>
#       <td>public</td>
#       <td>return_pf_part_viia</td>
#     </t

# %%
import shutil
shutil.rmtree('/home/jovyan/data/spark-warehouse/irs990.db')
spark.sql('DROP DATABASE IF EXISTS irs990 CASCADE;')
spark.sql("create database irs990")

# shutil.rmtree('/home/jovyan/data/spark-warehouse/irs990.db/address_table')
# shutil.rmtree('/home/jovyan/data/spark-warehouse/irs990.db/return_EZOffcrDrctrTrstEmpl')
# shutil.rmtree('/home/jovyan/data/spark-warehouse/irs990.db/tmp_990ez_employees')
# Out:
# DataFrame[]

# %%
# spark.sql('DROP TABLE IF EXISTS return_EZOffcrDrctrTrstEmpl')
# spark.sql('DROP TABLE IF EXISTS address_table')
# spark.sql('DROP TABLE IF EXISTS tmp_990ez_employees')
# Out:
# DataFrame[]

# %%
spark.sql("USE irs990")
# Out:
# DataFrame[]

# %%
return_EZOffcrDrctrTrstEmpl = spark.read \
    .format('jdbc') \
    .option('driver', properties['driver']) \
    .option('url', properties['url']) \
    .option('dbtable', "return_EZOffcrDrctrTrstEmpl") \
    .option('user', properties['user']) \
    .load()

# %%
address = spark.read \
    .format('jdbc') \
    .option('driver', properties['driver']) \
    .option('url', properties['url']) \
    .option('dbtable', 'address_table') \
    .option('user', properties['user']) \
    .load()

# %%
print(address.count())
print(return_EZOffcrDrctrTrstEmpl.count())
# Out:
# 2243560
# 4698799

# %%
print('Number of partitions: {}'.format(address.rdd.getNumPartitions()))
print('Number of partitions: {}'.format(return_EZOffcrDrctrTrstEmpl.rdd.getNumPartitions()))
# Out:
# Number of partitions: 1
# Number of partitions: 1

# %%
address = address.repartition(50)

# %%
return_EZOffcrDrctrTrstEmpl = return_EZOffcrDrctrTrstEmpl.repartition(50)

# %%
print('Number of partitions: {}'.format(address.rdd.getNumPartitions()))
print('Number of partitions: {}'.format(return_EZOffcrDrctrTrstEmpl.rdd.getNumPartitions()))
# Out:
# Number of partitions: 50
# Number of partitions: 50

# %%
address.write.saveAsTable("address_table")

# %%
spark.sql('SHOW TABLES IN irs990').show()
# Out:
# +--------+--------------------+-----------+
# |database|           tableName|isTemporary|
# +--------+--------------------+-----------+
# |  irs990|       address_table|      false|
# |  irs990|return_ezoffcrdrc...|      false|
# +--------+--------------------+-----------+

# %%
return_EZOffcrDrctrTrstEmpl.write.saveAsTable('return_EZOffcrDrctrTrstEmpl')

# %%
# %%time
sql_query_join = """
SELECT addt.*, rez.PrsnNm, rez.TtlTxt, rez.CmpnstnAmt
FROM return_EZOffcrDrctrTrstEmpl as rez
    LEFT JOIN address_table as addt
    ON rez.ein = addt.ein
    AND rez.object_id = addt.object_id
    ORDER BY addt.ein DESC, addt.object_id DESC;
"""

tmp_990ez_employees = spark.sql(sql_query_join)

tmp_990ez_employees.write.saveAsTable('tmp_990ez_employees')
# Out:
# CPU times: user 5.64 ms, sys: 2.3 ms, total: 7.94 ms
# Wall time: 36.2 s

# %%
# %%time
dat = spark.read.parquet("../../../data/spark-warehouse/irs990.db/tmp_990ez_employees/")
dat.count()
# Out:
# CPU times: user 3.33 ms, sys: 597 µs, total: 3.93 ms
# Wall time: 806 ms
# 4698887

# %%
# https://github.com/jsfenfen/990-xml-database/blob/master/directors.sh

# DROP TABLE IF EXISTS tmp_990ez_employees;
# SELECT address_table.*,
# 	'/IRS990EZ' as form,
#    "PrsnNm",
#    "TtlTxt",
#    "CmpnstnAmt" 
#    INTO temporary table tmp_990EZ_employees
#    FROM return_EZOffcrDrctrTrstEmpl
# 	LEFT JOIN address_table ON return_EZOffcrDrctrTrstEmpl.ein = address_table.ein
# 	AND return_EZOffcrDrctrTrstEmpl.object_id= address_table.object_id;

# %%
temp = tmp_990ez_employees.limit(100).toPandas()
temp
# Out:
#           ein           object_id RtrnHdr_TxPrdEndDt  RtrnHdr_TxYr  \
# 0   996078202  201921349349202282         2018-12-31          2018
# 1   996078202  201921349349202282         2018-12-31          2018
# 2   996078202  201921349349202282         2018-12-31          2018
# 3   996078202  201801289349200760         2017-12-31          2017
# 4   996078202  201801289349200760         2017-12-31          2017
# ..        ...                 ...                ...           ...
# 95  996022758  201413029349200641         2014-06-30          2013
# 96  996022758  201413029349200641         2014-06-30          2013
# 97  996022758  201413029349200641         2014-06-30          2013
# 98  996022758  201413029349200641         2014-06-30          2013
# 99  996022758  201413029349200641         2014-06-30          2013
#
#          BsnssNm_BsnssNmLn1Txt BsnssNm_BsnssNmLn2Txt BsnssOffcr_PrsnNm  \
# 0   JOSEPH CAMPBELL FOUNDATION       ENDOWMENT TRUST   EDWARD C HORTON
# 1   JOSEPH CAMPBELL FOUNDATION       ENDOWMENT TRUST   EDWARD C HORTON
# 2   JOSEPH CAMPBELL FOUNDATION       ENDOWMENT TRUST   EDWARD C HORTON
# 3   JOSEPH CAMPBELL FOUNDATION       ENDOWMENT TRUST   EDWARD C HORTON
# 4   JOSEPH CAMPBELL FOUNDATION       ENDOWMENT TRUST   EDWARD C HORTON
# ..                         ...                   ...               ...
# 95  PUNAHOU ALUMNI ASSOCIATION                  None     JENNIFER HONG
# 96  PUNAHOU ALUMNI ASSOCIATION                  None     JENNIFER HONG
# 97  PUNAHOU ALUMNI ASSOCIATION                  None     JENNIFER HONG
# 98  PUNAHOU ALUMNI ASSOCIATION                  None     JENNIFER HONG
# 99  PUNAHOU ALUMNI ASSOCIATION                  None     JENNIFER HONG
#
#    BsnssOffcr_PrsnTtlTxt BsnssOffcr_PhnNm BsnssOffcr_EmlAddrssTxt  ...  \
# 0                TRUSTEE       9732180500                    None  ...
# 1                TRUSTEE       9732180500                    None  ...
# 2                TRUSTEE       9732180500                    None  ...
# 3                TRUSTEE       9732180500                    None  ...
# 4                TRUSTEE       9732180500                    None  ...
# ..                   ...              ...                     ...  ...
# 95             TREASURER       8089445740                    None  ...
# 96             TREASURER       8089445740                    None  ...
# 97             TREASURER       8089445740                    None  ...
# 98             TREASURER       8089445740                    None  ...
# 99             TREASURER       8089445740                    None  ...
#
#    USAddrss_SttAbbrvtnCd USAddrss_ZIPCd FrgnAddrss_AddrssLn1Txt  \
# 0                     NY          10014                    None
# 1                     NY          10014                    None
# 2                     NY          10014                    None
# 3                     NY          10014                    None
# 4                     NY          10014                    None
# ..                   ...            ...                     ...
# 95                    HI          96822                    None
# 96                    HI          96822                    None
# 97                    HI          96822                    None
# 98                    HI          96822                    None
# 99                    HI          96822                    None
#
#    FrgnAddrss_AddrssLn2Txt FrgnAddrss_CtyNm FrgnAddrss_PrvncOrSttNm  \
# 0                     None             None                    None
# 1                     None             None                    None
# 2                     None             None                    None
# 3                     None             None                    None
# 4                     None             None                    None
# ..                     ...              ...                     ...
# 95                    None             None                    None
# 96                    None             None                    None
# 97                    None             None                    None
# 98                    None             None                    None
# 99                    None             None                    None
#
#    FrgnAddrss_CntryCd               PrsnNm                 TtlTxt CmpnstnAmt
# 0                None      EDWARD C HORTON                TRUSTEE          0
# 1                None        ROBERT WALTER                TRUSTEE          0
# 2                None  THEODORE DILLINGHAM                TRUSTEE          0
# 3                None        ROBERT WALTER                TRUSTEE          0
# 4                None  THEODORE DILLINGHAM                TRUSTEE          0
# ..                ...                  ...                    ...        ...
# 95               None      BONNIE-LEE PANG         PAST PRESIDENT          0
# 96               None        RICHARD ASATO              PRESIDENT          0
# 97               None          TREVER ASAM           BOARD MEMBER          0
# 98               None          RANDALL KAM  SECOND VICE PRESIDENT          0
# 99               None       CHRISTIAN FERN    ASSISTANT TREASURER          0
#
# [100 rows x 24 columns]
