# %% [markdown]
# ## Introduction to databricks
#
# - [Databricks Notebooks](https://docs.databricks.com/notebooks/notebooks-use.html)
#
# `![](https://docs.databricks.com/_images/short-cuts.png)`
#
# ![](https://docs.databricks.com/_images/short-cuts.png)

# %% [markdown]
# ## Examples of language specific chunks

# %%
# %python
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %r
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <pre style="font-size:10p"></pre><pre style = 'font-size:10pt'>NULL</pre>

# %%
 # %scala
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sql

# %% [markdown]
# `%md`

# %% [markdown]
# ## Other chunk features

# %% [markdown]
# - <a href="$./example_charts">Link to example_charts notebook</a>
# - <a href="$./example_data">Link to example_data notebook</a>
# - <a href="$./Machine Learning on Spark/Machine Learning on Spark">Link to nested notebook on ML</a>

# %% [markdown]
# ```
# \\(c = \\pm\\sqrt{a^2 + b^2} \\)
#
# \\(A{_i}{_j}=B{_i}{_j}\\)
#
# $$c = \\pm\\sqrt{a^2 + b^2}$$
#
# \\[A{_i}{_j}=B{_i}{_j}\\]
# ```
# \\(c = \\pm\\sqrt{a^2 + b^2} \\)
#
# \\(A{_i}{_j}=B{_i}{_j}\\)
#
# $$c = \\pm\\sqrt{a^2 + b^2}$$
#
# \\[A{_i}{_j}=B{_i}{_j}\\]

# %% [markdown]
# ```
# \\( f(\beta)= -Y_t^T X_t \beta + \sum log( 1+{e}^{X_t\bullet\beta}) + \frac{1}{2}\delta^t S_t^{-1}\delta\\)
#
# where \\(\delta=(\beta - \mu_{t-1})\\)
# ```
#
# \\( f(\beta)= -Y_t^T X_t \beta + \sum log( 1+{e}^{X_t\bullet\beta}) + \frac{1}{2}\delta^t S_t^{-1}\delta\\)
#
# where \\(\delta=(\beta - \mu_{t-1})\\)
